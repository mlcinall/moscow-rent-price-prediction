# %% [markdown]
# ---
#
# ### Методология сбора данных
#
# Для обучения модели оценки арендной стоимости в Москве используется выборка, сформированная на основе объявлений с сайта CIAN с помощью библиотеки `cianparser`. Цель — создать датасет, сбалансированный по ценовым сегментам, чтобы избежать переобучения модели на отдельных группах (например, слишком дешёвом или дорогом жилье) и обеспечить более реалистичное поведение модели на практике.
#
# #### Структура выборки
# - **Общий целевой объём:** ~16 000 объектов
# - **Ожидаемое распределение:**
#   - До 100 000 ₽: ~70%
#   - 100 000–250 000 ₽: ~30%
#
# #### Принципы сбалансированного сбора
# Данные загружаются по заранее заданным ценовым диапазонам (бином) — от эконом-сегмента до средне-высокого. Для каждого бина задаётся квота, отражающая **реальное распределение предложений на рынке**, с учётом ограничения сайта (до 54 страниц на диапазон) и доступности объявлений.
#
# > Такой подход позволяет получить выборку, близкую по структуре к текущему состоянию рынка, и избежать искажения метрик за счёт смещённого распределения. Модель, обученная на этих данных, будет лучше отражать реальные рыночные закономерности.
#
# ---

# %%
# !pip install cianparser
# Out:
# Collecting cianparser
#   Downloading cianparser-1.0.4-py3-none-any.whl.metadata (24 kB)
# Collecting cloudscraper (from cianparser)
#   Downloading cloudscraper-1.2.71-py2.py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from cianparser) (4.13.4)
# Collecting transliterate (from cianparser)
#   Downloading transliterate-1.10.2-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from cianparser) (5.4.0)
# Collecting datetime (from cianparser)
#   Downloading DateTime-5.5-py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->cianparser) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->cianparser) (4.14.1)
# Requirement already satisfied: pyparsing>=2.4.7 in /usr/local/lib/python3.11/dist-packages (from cloudscraper->cianparser) (3.2.3)
# Requirement already satisfied: requests>=2.9.2 in /usr/local/lib/python3.11/dist-packages (from cloudscraper->cianparser) (2.32.3)
# Requirement already satisfied: requests-toolbelt>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from cloudscraper->cianparser) (1.0.0)
# Collecting zope.interface (from datetime->cianparser)
#   Downloading zope.interface-7.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from datetime->cianparser) (2025.2)
# Requirement already satisfied: six>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from transliterate->cianparser) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.9.2->cloudscraper->cianparser) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.9.2->cloudscraper->cianparser) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.9.2->cloudscraper->cianparser) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.9.2->cloudscraper->cianparser) (2025.8.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from zope.interface->datetime->cianparser) (75.2.0)
# Downloading cianparser-1.0.4-py3-none-any.whl (32 kB)
# Downloading cloudscraper-1.2.71-py2.py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.7/99.7 kB 7.9 MB/s eta 0:00:00
# Downloading DateTime-5.5-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 kB 3.5 MB/s eta 0:00:00
# Downloading transliterate-1.10.2-py2.py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 3.5 MB/s eta 0:00:00
# Downloading zope.interface-7.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (259 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.8/259.8 kB 18.3 MB/s eta 0:00:00
# Installing collected packages: zope.interface, transliterate, datetime, cloudscraper, cianparser
# Successfully installed cianparser-1.0.4 cloudscraper-1.2.71 datetime-5.5 transliterate-1.10.2 zope.interface-7.2

# %%
from typing import List, Tuple
from cianparser import CianParser
import pandas as pd
import time
import math

def parse_cian_data(
    location: str,
    price_ranges: List[Tuple[int, int]],
    total_target: int,
    avail_counts: dict
) -> pd.DataFrame:
    """
    Собирает объявления с CIAN по заданным ценовым диапазонам, распределяя дефицит.
    """
    parser = CianParser(location=location)
    seen_urls = set()
    all_data = []

    shares = {"low": 0.70, "mid": 0.30}
    low_bins  = price_ranges[:8]
    mid_bins  = price_ranges[8:]

    group_targets = {
        "low":  int(total_target * shares["low"]),
        "mid":  int(total_target * shares["mid"]),
    }

    desired = {}
    for name, bins in [("low", low_bins), ("mid", mid_bins)]:
        n_total = group_targets[name]
        base    = n_total // len(bins)
        rem     = n_total % len(bins)
        for i, rng in enumerate(bins):
            desired[rng] = base + (1 if i < rem else 0)

    MAX_PAGES = 54
    MAX_PER_BIN = MAX_PAGES * 25  # ≈1350
    quotas = {}
    total_assigned = 0
    for rng, q in desired.items():
        avail = avail_counts.get(rng, 0)
        q0 = min(q, avail, MAX_PER_BIN)
        quotas[rng] = q0
        total_assigned += q0

    deficit = total_target - total_assigned
    if deficit > 0:
        extras = {
            rng: min(avail_counts.get(rng, 0), MAX_PER_BIN) - quotas[rng]
            for rng in price_ranges
        }
        total_extra = sum(v for v in extras.values() if v > 0)
        if total_extra > 0:
            for rng, cap in extras.items():
                if cap <= 0:
                    continue
                add = math.floor(deficit * (cap / total_extra))
                add = min(add, cap)
                quotas[rng] += add
                deficit -= add
            for rng, cap in sorted(extras.items(), key=lambda x: x[1], reverse=True):
                if deficit <= 0:
                    break
                if cap > 0:
                    add = min(cap, deficit)
                    quotas[rng] += add
                    deficit -= add

    for (lo, hi), target in quotas.items():
        print(f"\nДиапазон {lo}–{hi}: целевая квота {target}")
        collected = 0
        page = 1
        while collected < target and page <= MAX_PAGES:
            data = parser.get_flats(
                deal_type="rent_long", rooms="all", with_saving_csv=False,
                additional_settings={"min_price": lo, "max_price": hi,
                                     "start_page": page, "end_page": page}
            )
            if not data:
                break
            new_items = [d for d in data if d["url"] not in seen_urls]
            if new_items:
                need = target - collected
                batch = new_items[:need]
                all_data.extend(batch)
                seen_urls.update(d["url"] for d in batch)
                collected += len(batch)
            page += 1
            time.sleep(2)
        print(f"  Собрано {collected}/{target}")

    df = pd.DataFrame(all_data)

    return df

# %%
PRICE_RANGES = [
    (30001,40000),(40001,45000),(45001,50000),
    (50001,55000),(55001,60000),(60001,65000),(65001,70000),
    (70001,80000),(80001,90000),(90001,100000),
    (100001,120000),(120001,140000),(140001,180000),
    (180001,250000)
]

AVAIL_COUNTS = {
    (30001,40000):517, (40001,45000):750,
    (45001,50000):1250,(50001,55000):1250,(55001,60000):1500,
    (60001,65000):1300,(65001,70000):1350,(70001,80000):2200,
    (80001,90000):1650,(90001,100000):1350,(100001,120000):1700,
    (120001,140000):1150,(140001,180000):1350,(180001,250000):1350
}

TOTAL_TARGET = 16_000
LOCATION = "Москва"

data = parse_cian_data(
    location=LOCATION,
    price_ranges=PRICE_RANGES,
    total_target=TOTAL_TARGET,
    avail_counts=AVAIL_COUNTS
)
# Out:
# 🔎 Диапазон 0–30000: целевая квота 113
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=2&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 2 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 104 226 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=3&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 3 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 111 031 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=4&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 4 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 25. Progress ratio: 100 %. Average price: 98 197 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 25.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=5&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 5 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=6&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 6 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=7&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 7 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=8&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 8 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=9&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 9 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=10&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 10 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=11&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 11 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=12&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 12 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=13&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 13 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=14&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 14 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=15&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 15 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=16&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 16 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=17&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 17 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=18&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 18 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=19&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 19 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=20&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 20 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=21&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 21 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=22&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 22 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=23&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 23 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=24&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 24 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=25&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 25 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=26&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 26 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=27&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 27 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=28&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 28 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=29&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 29 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=30&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 30 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=31&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 31 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=32&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 32 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=33&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 33 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=34&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 34 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=35&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 35 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=36&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 36 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=37&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 37 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=38&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 38 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=39&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 39 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=40&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 40 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=41&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 41 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=42&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 42 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=43&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 43 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=44&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 44 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=45&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 45 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=46&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 46 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=47&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 47 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=48&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 48 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=49&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 49 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=50&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 50 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=51&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 51 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=52&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 52 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=53&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 53 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=54&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=0&maxprice=30000
#
# Collecting information from pages with list of offers
#  1 | 54 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 114 682 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#   Собрано 109/113
#
# 🔎 Диапазон 30001–40000: целевая квота 1078
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=30001&maxprice=40000
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 146 714 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=2&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=30001&maxprice=40000
#
# Collecting information from pages with list of offers
#  1 | 2 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 151 231 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=3&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=30001&maxprice=40000
#
# Collecting information from pages with list of offers
#  1 | 3 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 146 514 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=4&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=30001&maxprice=40000
#
# Collecting information from pages with list of offers
#  1 | 4 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 148 181 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=5&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=30001&maxprice=40000
#
# Collecting information from pages with list of offers
#  1 | 5 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 148 134 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=6&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=30001&maxprice=40000
#
# Collecting information from pages with list of offers
#  1 | 6 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 144 273 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=7&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=30001&maxprice=40000
#
# Collecting information from pages with list of offers
#  1 | 7 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 148 222 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=8&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=30001&maxprice=40000
#
# Collecting information from pages with list of offers
#  1 | 8 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 147 037 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=9&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=30001&maxprice=40000
#
# Collecting information from pages with list of offers
#  1 | 9 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 145 849 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=10&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=30001&maxprice=40000
#
# Collecting information from pages with list of offers
#  1 | 10 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 150 989 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=11&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=30001&maxprice=40000
#
# Collecting information from pages with list of offers
#  1 | 11 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 147 929 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=12&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=30001&maxprice=40000
#
# Collecting information from pages with list of offers
#  1 | 12 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 145 385 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=13&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=30001&maxprice=40000
#
# Collecting information from pages with list of offers
#  1 | 13 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 143 368 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=14&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=30001&maxprice=40000
#
# Collecting information from pages with list of offers
#  1 | 14 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 151 055 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=15&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=30001&maxprice=40000
#
# Collecting information from pages with list of offers
#  1 | 15 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 146 058 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=16&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=30001&maxprice=40000
#
# Collecting information from pages with list of offers
#  1 | 16 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 147 277 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=17&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=30001&maxprice=40000
#
# Collecting information from pages with list of offers
#  1 | 17 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 150 421 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=18&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=30001&maxprice=40000
#
# Collecting information from pages with list of offers
#  1 | 18 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 149 234 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=19&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=30001&maxprice=40000
#
# Collecting information from pages with list of offers
#  1 | 19 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 146 439 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=20&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=30001&maxprice=40000
#
# Collecting information from pages with list of offers
#  1 | 20 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 148 180 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=21&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=30001&maxprice=40000
#
# Collecting information from pages with list of offers
#  1 | 21 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 148 425 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=22&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=30001&maxprice=40000
#
# Collecting information from pages with list of offers
#  1 | 22 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 144 118 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=23&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=30001&maxprice=40000
#
# Collecting information from pages with list of offers
#  1 | 23 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 145 815 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=24&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=30001&maxprice=40000
#
# Collecting information from pages with list of offers
#  1 | 24 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 140 047 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=25&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=30001&maxprice=40000
#
# Collecting information from pages with list of offers
# ...
#  1 | 45 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 695 362 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=46&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=160001&maxprice=180000
#
# Collecting information from pages with list of offers
#  1 | 46 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 695 362 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=47&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=160001&maxprice=180000
#
# Collecting information from pages with list of offers
#  1 | 47 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 695 362 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=48&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=160001&maxprice=180000
#
# Collecting information from pages with list of offers
#  1 | 48 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 695 362 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=49&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=160001&maxprice=180000
#
# Collecting information from pages with list of offers
#  1 | 49 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 695 362 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=50&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=160001&maxprice=180000
#
# Collecting information from pages with list of offers
#  1 | 50 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 695 362 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=51&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=160001&maxprice=180000
#
# Collecting information from pages with list of offers
#  1 | 51 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 695 362 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=52&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=160001&maxprice=180000
#
# Collecting information from pages with list of offers
#  1 | 52 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 695 362 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=53&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=160001&maxprice=180000
#
# Collecting information from pages with list of offers
#  1 | 53 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 695 362 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=54&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=160001&maxprice=180000
#
# Collecting information from pages with list of offers
#  1 | 54 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 695 362 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#   Собрано 507/529
#
# 🔎 Диапазон 180001–200000: целевая квота 398
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=180001&maxprice=200000
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 774 014 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=2&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=180001&maxprice=200000
#
# Collecting information from pages with list of offers
#  1 | 2 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 778 339 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=3&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=180001&maxprice=200000
#
# Collecting information from pages with list of offers
#  1 | 3 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 767 269 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=4&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=180001&maxprice=200000
#
# Collecting information from pages with list of offers
#  1 | 4 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 770 613 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=5&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=180001&maxprice=200000
#
# Collecting information from pages with list of offers
#  1 | 5 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 761 041 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=6&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=180001&maxprice=200000
#
# Collecting information from pages with list of offers
#  1 | 6 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 774 192 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=7&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=180001&maxprice=200000
#
# Collecting information from pages with list of offers
#  1 | 7 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 775 361 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=8&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=180001&maxprice=200000
#
# Collecting information from pages with list of offers
#  1 | 8 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 770 996 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=9&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=180001&maxprice=200000
#
# Collecting information from pages with list of offers
#  1 | 9 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 774 266 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=10&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=180001&maxprice=200000
#
# Collecting information from pages with list of offers
#  1 | 10 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 777 984 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=11&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=180001&maxprice=200000
#
# Collecting information from pages with list of offers
#  1 | 11 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 767 487 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=12&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=180001&maxprice=200000
#
# Collecting information from pages with list of offers
#  1 | 12 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 776 440 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=13&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=180001&maxprice=200000
#
# Collecting information from pages with list of offers
#  1 | 13 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 768 964 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=14&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=180001&maxprice=200000
#
# Collecting information from pages with list of offers
#  1 | 14 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 772 857 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=15&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=180001&maxprice=200000
#
# Collecting information from pages with list of offers
#  1 | 15 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 774 014 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=16&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=180001&maxprice=200000
#
# Collecting information from pages with list of offers
#  1 | 16 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 774 014 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=17&with_neighbors=0&region=1&deal_type=rent&offer_type=flat&type=4&minprice=180001&maxprice=200000

# %%
print(f"\nВсего в датасете: {len(data)} объявлений (цель {TOTAL_TARGET})")
data.to_csv(f"cian_rent_Moscow_balanced.csv", index=False, encoding="utf-8-sig")
print(f"Готово! Датасет сохранён как cian_rent_Moscow_balanced.csv")
